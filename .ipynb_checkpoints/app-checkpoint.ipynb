# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from pandas.plotting import radviz
from sklearn.impute import SimpleImputer
import math
from sklearn import svm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from R_square_clustering import r_square
from sklearn. cluster import KMeans
from sklearn.decomposition import PCA
from scipy.cluster import hierarchy

# %%
data = pd.read_csv("base_prospect.csv", encoding='latin-1')

labels =[ 'dept', 'effectif', 'ca_total_FL', 'ca_export_FK', 'endettement',
       'evo_benefice', 'ratio_benef', 'evo_effectif', 'evo_risque', 'age',
       'chgt_dir', 'rdv']

# %%
for label in data.columns:
	nan  = data.loc[lambda df: df[label].isnull()]
	nombre = len(nan[label])
	percent = (nombre*100)/float(np.size(data,0))
	if(percent >0):
                print("=========="+label+"==========")
                print("nombre 	:"+str(nombre))
                print("Pourcentage 	:"+str(percent))
                plt.pie([percent,100-percent], labels=["NA","other"], autopct='%.0f%%')
                plt.title(label)
                plt.savefig("images/"+label)
                plt.close()
#plt.plot(data.ca_total_FL,data.ratio_benef)
#plt.scatter(data.ca_total_FL,data.ratio_benef)
#plt.savefig("corr")
# Out:
# ==========ca_export_FK==========
# nombre 	:6477
# Pourcentage 	:5.965406719717064
# ==========risque==========
# nombre 	:936
# Pourcentage 	:0.8620689655172413
# ==========evo_risque==========
# nombre 	:1538
# Pourcentage 	:1.416519304450339
# ==========type_com==========
# nombre 	:1079
# Pourcentage 	:0.9937739463601533
# ==========chgt_dir==========
# nombre 	:35766
# Pourcentage 	:32.94098143236074

# %%
#Encodage et nature de données.

"""
   ==========risque==========
  nombre  :936
  Pourcentage   :0.862068965517

  Pourcentage trés faible correspondant à  936 lignes.
  => suppression des lignes
  les notes sont supposées etre toutes superieur ou égal à 7.
  donc on supprime aussi les instances don le risque est "1-6"
  Encodage:

"""
risque_undefined_rows = data.loc[lambda df: df['risque'].isna()]

data = data.drop(risque_undefined_rows.index)


"""
  ==========evo_risque==========
  nombre  :1538
  Pourcentage   :1.41651930445

  Pourcentage faible correspondant à 1538 ligne.

  On remarque aussi que 87% de ces instances(où evo_risque == NA) on pour valeur de rdv =0.
  vu qu'à la base 89.7 % des instances de la base on un rdv =0, donc la meilleure solution est d'effacer
  toutes les instances dont la colonne evo_risque == NA pour que cet attribut soit un peu plus discrminant pour l'attribut rdv.
  
"""
evo_risque_undefined_rows = data.loc[lambda df: df['evo_risque'].isna()]
data = data.drop(evo_risque_undefined_rows.index)



"""
  ==========type_com==========
  nombre  :1079
  Pourcentage   :0.99377394636
  pourcentage trés faible correspondant à 1079 lignes.
"""
type_com_undefined_rows = data.loc[lambda df: df['type_com'].isna()]
data =data.drop(type_com_undefined_rows.index)

"""
  ==========chgt_dir==========
  nombre  :35766
  Pourcentage   :32.9409814324
  attribut de nature catégoricale encodé en numérique [0,1].
  pourcentage trés elevés.
  La meilleure solution est de créer une nouvelle categorie reprensenté par 2.
"""
data['chgt_dir']=data['chgt_dir'].apply(lambda x: 2 if math.isnan(x) else x)

"""
  ==========ca_export_FK==========
  nombre  :6477
  Pourcentage   :5.96540671972
  iL ya de valeurs manquantes dans cette colonne correspondant à 5.97 % des donnees de la base.
  => Correspond à 6477, un chiffre non negligeable.
  Solutions:
    - remplacement des valeurs par la moyenne de la plage de valeurs grace à la classe SimpleImputer de la librairie sklearn.

"""
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
data[['ca_export_FK','evo_risque']]=imp_mean.fit_transform(data[['ca_export_FK','evo_risque']])

# %%
standardscaler = preprocessing.StandardScaler()
X_norm = standardscaler.fit_transform(data[labels])
labels.remove('rdv')
labels.remove('dept')
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.5/dist-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
'''
profil : geographique
'''
'''
  CLASSIFICATION NON SUPERVISE( k-MEAN)
'''

'''lst_k=range(1,20)
lst_rsq = []
for k in lst_k:
    est=KMeans(n_clusters=k)
    est.fit (X_norm)
    lst_rsq.append(r_square(X_norm, est.cluster_centers_,est.labels_,k))
fig = plt. figure ()
plt.plot(lst_k, lst_rsq, 'bx-')
plt.xlabel('k')
plt.ylabel('RSQ')
plt.title ('The Elbow Method showing the optimal k')
plt.savefig('images/r_square')
plt.close(fig)'''
# Out:
# "lst_k=range(1,20)\nlst_rsq = []\nfor k in lst_k:\n    est=KMeans(n_clusters=k)\n    est.fit (X_norm)\n    lst_rsq.append(r_square(X_norm, est.cluster_centers_,est.labels_,k))\nfig = plt. figure ()\nplt.plot(lst_k, lst_rsq, 'bx-')\nplt.xlabel('k')\nplt.ylabel('RSQ')\nplt.title ('The Elbow Method showing the optimal k')\nplt.savefig('images/r_square')\nplt.close(fig)"

# %%
pca = PCA(n_components=2)
data['x'] = pca.fit_transform(X_norm)[:,0]
data['y'] = pca.fit_transform(X_norm)[:,1]

# %%
cmap = cm.get_cmap('gnuplot')
est=KMeans(n_clusters=12)

data['clusters'] = est.fit_predict(data[labels])
labels.extend(['clusters','rdv','dept','code_cr','x','y'])
centroids = est.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='o',
            cmap=cmap)

plt.title("11 clusters")
plt.savefig("images/kmeans")

# %%
'''plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='d',
            cmap=cmap)
plt.scatter(data.loc[lambda df:df['rdv']==0]['x'], data.loc[lambda df:df['rdv']==0]['y'],marker='o', cmap=cmap)
'''
# Out:
# "plt.scatter(centroids[:, 0], centroids[:, 1],\n            marker='d',\n            cmap=cmap)\nplt.scatter(data.loc[lambda df:df['rdv']==0]['x'], data.loc[lambda df:df['rdv']==0]['y'],marker='o', cmap=cmap)\n"

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labs = ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4', 'cluster 5', 'cluster 6', 'cluster 7', 'cluster 8','cluster 9','cluster 10','cluster 11','cluster 12']
fig1, ax1 = plt.subplots(1,2)
ax1[0].pie(data.groupby(['clusters']).count()['rdv'].values,labels=labs, autopct='%1.2f%%',
        shadow=False, startangle=360)
m=[]
gt = data.loc[lambda df:df['rdv']==1.0].groupby('clusters').count()['rdv']
print(gt)
for lab in labs:
    index = labs.index(lab)
    if index not in gt.index:
        m.append(0)
    else:
        m.append(gt[index])
nbre=[]
cls=[]
r=[]
a=""
somm=0
for i,s in zip(m,labs):
    if i>10:
        nbre.append(i)
        cls.append(s)
    else:
        if s[8] not in a:
            a=a+"-"+s[8:]
        somm =somm+i
cls.append("clusters"+a)
nbre.append(somm)
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

ax1[1].pie(nbre,labels=cls, autopct='%1.2f%%',
        shadow=False, startangle=90)

plt.title("rdv par rapport aux clusters")
plt.savefig("images/rdv-clusters")
plt.close()
print(gt)
# Out:
# clusters
# 0     9704
# 1        1
# 2        3
# 4       35
# 5      878
# 7        1
# 8       10
# 11     191
# Name: rdv, dtype: int64
# 'nbre=[]\ncls=[]\nr=[]\na=""\nsomm=0\nfor i,s in zip(m,labs):\n    if i>10:\n        nbre.append(i)\n        cls.append(s)\n    else:\n        if s[8] not in a:\n            a=a+"-"+s[8:]\n        somm =somm+i\ncls.append("clusters"+a)\nnbre.append(somm)\nexplode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. \'Hogs\')\n\nax1[1].pie(nbre,labels=cls, autopct=\'%1.2f%%\',\n        shadow=False, startangle=90)\n\nplt.title("rdv par rapport aux clusters")\nplt.savefig("images/rdv-clusters")\nplt.close()\nprint(gt)'

# %%
ht = data.groupby(['clusters','code_cr','rdv']).count()
ht
# Out:
#                        dept  effectif  ca_total_FL  ca_export_FK  risque  \
# clusters code_cr rdv
# 0        GALS    0      919       919          919           919     919
#                  1      105       105          105           105     105
#          GAM     0     7604      7604         7604          7604    7604
#                  1      936       936          936           936     936
#          GCA     0     4703      4703         4703          4703    4703
#                  1      725       725          725           725     725
#          GCM     0     4130      4130         4130          4130    4130
#                  1      619       619          619           619     619
#          GGE     0     6870      6870         6870          6870    6870
#                  1      891       891          891           891     891
#          GNE     0     8495      8495         8495          8495    8495
#                  1     1057      1057         1057          1057    1057
#          GOC     0     8441      8441         8441          8441    8441
#                  1     1355      1355         1355          1355    1355
#          GPVL    0    13984     13984        13984         13984   13984
#                  1     1423      1423         1423          1423    1423
#          GRAA    0    17926     17926        17926         17926   17926
#                  1     1949      1949         1949          1949    1949
#          GSUD    0     4737      4737         4737          4737    4737
#                  1      644       644          644           644     644
# 1        GALS    0        3         3            3             3       3
#          GNE     0        5         5            5             5       5
#                  1        1         1            1             1       1
#          GSUD    0        5         5            5             5       5
# 2        GALS    0       13        13           13            13      13
#          GGE     0        5         5            5             5       5
#          GNE     0       15        15           15            15      15
#          GOC     0        6         6            6             6       6
#                  1        2         2            2             2       2
#          GPVL    0       20        20           20            20      20
# ...                     ...       ...          ...           ...     ...
# 8        GOC     0        3         3            3             3       3
#          GPVL    0       34        34           34            34      34
#                  1        2         2            2             2       2
#          GSUD    0       12        12           12            12      12
# 9        GNE     0        4         4            4             4       4
#          GOC     0        5         5            5             5       5
#          GPVL    0        3         3            3             3       3
# 10       GALS    0        1         1            1             1       1
#          GNE     0        7         7            7             7       7
#          GSUD    0        1         1            1             1       1
# 11       GALS    0      173       173          173           173     173
#                  1        9         9            9             9       9
#          GAM     0      284       284          284           284     284
#                  1       21        21           21            21      21
#          GCA     0      146       146          146           146     146
#                  1        8         8            8             8       8
#          GCM     0       15        15           15            15      15
#                  1        1         1            1             1       1
#          GGE     0      327       327          327           327     327
#                  1       11        11           11            11      11
#          GNE     0      433       433          433           433     433
#                  1       23        23           23            23      23
#          GOC     0      182       182          182           182     182
#                  1       13        13           13            13      13
#          GPVL    0      695       695          695           695     695
#                  1       45        45           45            45      45
#          GRAA    0      766       766          766           766     766
#                  1       35        35           35            35      35
#          GSUD    0      237       237          237           237     237
#                  1       25        25           25            25      25
#
#                       endettement  evo_benefice  ratio_benef  evo_effectif  \
# clusters code_cr rdv
# 0        GALS    0            919           919          919           919
#                  1            105           105          105           105
#          GAM     0           7604          7604         7604          7604
#                  1            936           936          936           936
#          GCA     0           4703          4703         4703          4703
#                  1            725           725          725           725
#          GCM     0           4130          4130         4130          4130
#                  1            619           619          619           619
#          GGE     0           6870          6870         6870          6870
#                  1            891           891          891           891
#          GNE     0           8495          8495         8495          8495
#                  1           1057          1057         1057          1057
#          GOC     0           8441          8441         8441          8441
#                  1           1355          1355         1355          1355
#          GPVL    0          13984         13984        13984         13984
#                  1           1423          1423         1423          1423
#          GRAA    0          17926         17926        17926         17926
#                  1           1949          1949         1949          1949
#          GSUD    0           4737          4737         4737          4737
#                  1            644           644          644           644
# 1        GALS    0              3             3            3             3
#          GNE     0              5             5            5             5
#                  1              1             1            1             1
#          GSUD    0              5             5            5             5
# 2        GALS    0             13            13           13            13
#          GGE     0              5             5            5             5
#          GNE     0             15            15           15            15
#          GOC     0              6             6            6             6
#                  1              2             2            2             2
#          GPVL    0             20            20           20            20
# ...                           ...           ...          ...           ...
# 8        GOC     0              3             3            3             3
#          GPVL    0             34            34           34            34
#                  1              2             2            2             2
#          GSUD    0             12            12           12            12
# 9        GNE     0              4             4            4             4
#          GOC     0              5             5            5             5
#          GPVL    0              3             3            3             3
# 10       GALS    0              1             1            1             1
#          GNE     0              7             7            7             7
#          GSUD    0              1             1            1             1
# 11       GALS    0            173           173          173           173
#                  1              9             9            9             9
#          GAM     0            284           284          284           284
#                  1             21            21           21            21
#          GCA     0            146           146          146           146
#                  1              8             8            8             8
#          GCM     0             15            15           15            15
#                  1              1             1            1             1
#          GGE     0            327           327          327           327
#                  1             11            11           11            11
#          GNE     0            433           433          433           433
#                  1             23            23           23            23
#          GOC     0            182           182          182           182
#                  1             13            13           13            13
#          GPVL    0            695           695          695           695
#                  1             45            45           45            45
#          GRAA    0            766           766          766           766
#                  1             35            35           35            35
#          GSUD    0            237           237          237           237
#                  1             25            25           25            25
#
#                       evo_risque    age  type_com  activite  actionnaire  \
# clusters code_cr rdv
# 0        GALS    0           919    919       919       919          919
#                  1           105    105       105       105          105
#          GAM     0          7604   7604      7604      7604         7604
#                  1           936    936       936       936          936
#          GCA     0          4703   4703      4703      4703         4703
#                  1           725    725       725       725          725
#          GCM     0          4130   4130      4130      4130         4130
#                  1           619    619       619       619          619
#          GGE     0          6870   6870      6870      6870         6870
#                  1           891    891       891       891          891
#          GNE     0          8495   8495      8495      8495         8495
#                  1          1057   1057      1057      1057         1057
#          GOC     0          8441   8441      8441      8441         8441
#                  1          1355   1355      1355      1355         1355
#          GPVL    0         13984  13984     13984     13984        13984
#                  1          1423   1423      1423      1423         1423
#          GRAA    0         17926  17926     17926     17926        17926
#                  1          1949   1949      1949      1949         1949
#          GSUD    0          4737   4737      4737      4737         4737
#                  1           644    644       644       644          644
# 1        GALS    0             3      3         3         3            3
#          GNE     0             5      5         5         5            5
#                  1             1      1         1         1            1
#          GSUD    0             5      5         5         5            5
# 2        GALS    0            13     13        13        13           13
#          GGE     0             5      5         5         5            5
#          GNE     0            15     15        15        15           15
#          GOC     0             6      6         6         6            6
#                  1             2      2         2         2            2
#          GPVL    0            20     20        20        20           20
# ...                          ...    ...       ...       ...          ...
# 8        GOC     0             3      3         3         3            3
#          GPVL    0            34     34        34        34           34
#                  1             2      2         2         2            2
#          GSUD    0            12     12        12        12           12
# 9        GNE     0             4      4         4         4            4
#          GOC     0             5      5         5         5            5
#          GPVL    0             3      3         3         3            3
# 10       GALS    0             1      1         1         1            1
#          GNE     0             7      7         7         7            7
#          GSUD    0             1      1         1         1            1
# 11       GALS    0           173    173       173       173          173
#                  1             9      9         9         9            9
#          GAM     0           284    284       284       284          284
#                  1            21     21        21        21           21
#          GCA     0           146    146       146       146          146
#                  1             8      8         8         8            8
#          GCM     0            15     15        15        15           15
#                  1             1      1         1         1            1
#          GGE     0           327    327       327       327          327
#                  1            11     11        11        11           11
#          GNE     0           433    433       433       433          433
#                  1            23     23        23        23           23
#          GOC     0           182    182       182       182          182
#                  1            13     13        13        13           13
#          GPVL    0           695    695       695       695          695
#                  1            45     45        45        45           45
#          GRAA    0           766    766       766       766          766
#                  1            35     35        35        35           35
#          GSUD    0           237    237       237       237          237
#                  1            25     25        25        25           25
#
#                       forme_jur_simpl  chgt_dir      x      y
# clusters code_cr rdv
# 0        GALS    0                919       919    919    919
#                  1                105       105    105    105
#          GAM     0               7604      7604   7604   7604
#                  1                936       936    936    936
#          GCA     0               4703      4703   4703   4703
#                  1                725       725    725    725
#          GCM     0               4130      4130   4130   4130
#                  1                619       619    619    619
#          GGE     0               6870      6870   6870   6870
#                  1                891       891    891    891
#          GNE     0               8495      8495   8495   8495
#                  1               1057      1057   1057   1057
#          GOC     0               8441      8441   8441   8441
#                  1               1355      1355   1355   1355
#          GPVL    0              13984     13984  13984  13984
#                  1               1423      1423   1423   1423
#          GRAA    0              17926     17926  17926  17926
#                  1               1949      1949   1949   1949
#          GSUD    0               4737      4737   4737   4737
#                  1                644       644    644    644
# 1        GALS    0                  3         3      3      3
#          GNE     0                  5         5      5      5
#                  1                  1         1      1      1
#          GSUD    0                  5         5      5      5
# 2        GALS    0                 13        13     13     13
#          GGE     0                  5         5      5      5
#          GNE     0                 15        15     15     15
#          GOC     0                  6         6      6      6
#                  1                  2         2      2      2
#          GPVL    0                 20        20     20     20
# ...                               ...       ...    ...    ...
# 8        GOC     0                  3         3      3      3
#          GPVL    0                 34        34     34     34
#                  1                  2         2      2      2
#          GSUD    0                 12        12     12     12
# 9        GNE     0                  4         4      4      4
#          GOC     0                  5         5      5      5
#          GPVL    0                  3         3      3      3
# 10       GALS    0                  1         1      1      1
#          GNE     0                  7         7      7      7
#          GSUD    0                  1         1      1      1
# 11       GALS    0                173       173    173    173
#                  1                  9         9      9      9
#          GAM     0                284       284    284    284
#                  1                 21        21     21     21
#          GCA     0                146       146    146    146
#                  1                  8         8      8      8
#          GCM     0                 15        15     15     15
#                  1                  1         1      1      1
#          GGE     0                327       327    327    327
#                  1                 11        11     11     11
#          GNE     0                433       433    433    433
#                  1                 23        23     23     23
#          GOC     0                182       182    182    182
#                  1                 13        13     13     13
#          GPVL    0                695       695    695    695
#                  1                 45        45     45     45
#          GRAA    0                766       766    766    766
#                  1                 35        35     35     35
#          GSUD    0                237       237    237    237
#                  1                 25        25     25     25
#
# [118 rows x 18 columns]

# %%
clf = svm.SVC(gamma='scale')

X_train, X_test, y_train, y_test = train_test_split(data[labels], data['rdv'], test_size = 0.20) 
clf.fit(X_train, y_train)
